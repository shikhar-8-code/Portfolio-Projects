# %% [markdown]
# Installing the mysql connector to connect to database

# %%
pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.31-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: protobuf<=3.20.1,>=3.11.0 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from mysql-connector-python) (3.19.1)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.0.31
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importing the required modules and libraries

# %%
import mysql.connector
import pandas as pd

# %% [markdown]
# Connecting to the database

# %%
def create_database():
    #connecting to the default database
    conn = mysql.connector.connect(
        host = "127.0.0.1",
        user = "root",
        password = "ShikharMac@8"
    )
    conn.autocommit = True
    curr = conn.cursor()
    
    #create database
    curr.execute("DROP DATABASE IF EXISTS netflix")
    curr.execute("CREATE DATABASE netflix")
    
    #close connection
    conn.close()
    
    conn = mysql.connector.connect(
        host = "127.0.0.1",
        database = "netflix",
        user = "root",
        password = "ShikharMac@8"
    )
    curr = conn.cursor()
    
    return curr, conn

# %%
def drop_tables(curr, conn):
    for query in drop_tables_queries:
        curr.execute(query)
        conn.commit()

# %%
def create_tables(curr, conn):
    for query in create_tables_queries:
        curr.execute(query)
        conn.commit()

# %% [markdown]
# Reading the csv datas into the dataframes through pandas library

# %%
RawCredits = pd.read_csv("/Users/shikharyadav/Desktop/Semester 2 - Spring 2023/Portfolio Projects/Netflix - Data Modeling & Exploration/raw_credits.csv")

# %%
RawTitles = pd.read_csv("/Users/shikharyadav/Desktop/Semester 2 - Spring 2023/Portfolio Projects/Netflix - Data Modeling & Exploration/raw_titles.csv")

# %%
RawCredits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
RawTitles.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3   tm70993                        Life of Brian  MOVIE          1979
# 4  tm190788                         The Exorcist  MOVIE          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# 2                PG       91  ['comedy', 'fantasy']               ['GB']
# 3                 R       94             ['comedy']               ['GB']
# 4                 R      133             ['horror']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes
# 0      1.0        NaN         NaN         NaN
# 1      NaN  tt0075314         8.3    795222.0
# 2      NaN  tt0071853         8.2    530877.0
# 3      NaN  tt0079470         8.0    392419.0
# 4      NaN  tt0070047         8.1    391942.0

# %% [markdown]
# Performing data cleaning

# %%
#removing the square brackets from genres and production_countries columns
rem_chars = "\]|\'|\[|\."
RawTitles['genres'] = RawTitles['genres'].str.replace(rem_chars, "", regex = True)
RawTitles['production_countries'] = RawTitles['production_countries'].str.replace(rem_chars, "", regex = True)

RawTitles.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3   tm70993                        Life of Brian  MOVIE          1979
# 4  tm190788                         The Exorcist  MOVIE          1973
#
#   age_certification  runtime           genres production_countries  seasons  \
# 0             TV-MA       48    documentation                   US      1.0
# 1                 R      113     crime, drama                   US      NaN
# 2                PG       91  comedy, fantasy                   GB      NaN
# 3                 R       94           comedy                   GB      NaN
# 4                 R      133           horror                   US      NaN
#
#      imdb_id  imdb_score  imdb_votes
# 0        NaN         NaN         NaN
# 1  tt0075314         8.3    795222.0
# 2  tt0071853         8.2    530877.0
# 3  tt0079470         8.0    392419.0
# 4  tt0070047         8.1    391942.0

# %%
#removing rows where at least one element is missing
RawCredits = RawCredits.dropna()

# %%
#removing duplicates in the rawcredits dataframe
RawCredits.drop_duplicates(subset = 'person_id', keep = False, inplace = True)
#RawCredits.drop_duplicates(subset = 'id', keep = False, inplace = True)

# %%
#having multiple values in genres is not helpful in model building so keeping just the first values in genres
RawTitles['genres'] = RawTitles['genres'].str.split(',').str[0]
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3   tm70993                        Life of Brian  MOVIE          1979
# 4  tm190788                         The Exorcist  MOVIE          1973
#
#   age_certification  runtime         genres production_countries  seasons  \
# 0             TV-MA       48  documentation                   US      1.0
# 1                 R      113          crime                   US      NaN
# 2                PG       91         comedy                   GB      NaN
# 3                 R       94         comedy                   GB      NaN
# 4                 R      133         horror                   US      NaN
#
#      imdb_id  imdb_score  imdb_votes
# 0        NaN         NaN         NaN
# 1  tt0075314         8.3    795222.0
# 2  tt0071853         8.2    530877.0
# 3  tt0079470         8.0    392419.0
# 4  tt0070047         8.1    391942.0

# %%
#renaming Genres to Genre
RawTitles = RawTitles.rename(columns = {'genres':'Genre'})

# %%
RawTitles.head()
# Out:
#          id                                title   type  release_year  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW          1945
# 1   tm84618                          Taxi Driver  MOVIE          1976
# 2  tm127384      Monty Python and the Holy Grail  MOVIE          1975
# 3   tm70993                        Life of Brian  MOVIE          1979
# 4  tm190788                         The Exorcist  MOVIE          1973
#
#   age_certification  runtime          Genre production_countries  seasons  \
# 0             TV-MA       48  documentation                   US      1.0
# 1                 R      113          crime                   US      NaN
# 2                PG       91         comedy                   GB      NaN
# 3                 R       94         comedy                   GB      NaN
# 4                 R      133         horror                   US      NaN
#
#      imdb_id  imdb_score  imdb_votes
# 0        NaN         NaN         NaN
# 1  tt0075314         8.3    795222.0
# 2  tt0071853         8.2    530877.0
# 3  tt0079470         8.0    392419.0
# 4  tt0070047         8.1    391942.0

# %%
#storing the returnable objects of create_database function
curr, conn = create_database()

# %% [markdown]
# Creating the tables in the database

# %%
#curr.execute('DROP TABLE rawtitles')

rawtitles_table_create = ("""CREATE TABLE IF NOT EXISTS rawtitles(
id VARCHAR (255) PRIMARY KEY,
title VARCHAR(500),
type VARCHAR(255),
release_year VARCHAR(4),
age_certification VARCHAR(50),
runtime INT,
genre VARCHAR(500),
production_countries VARCHAR(500),
seasons INT,
imdb_id VARCHAR(255),
imdb_score FLOAT,
imdb_votes INT)
""")

curr.execute(rawtitles_table_create)
conn.commit()

# %%
#curr.execute('DROP TABLE rawcredits')

rawcredits_table_create = ("""CREATE TABLE IF NOT EXISTS rawcredits(
person_id VARCHAR(255) PRIMARY KEY,
id VARCHAR(255),
name VARCHAR(500),
fic_character VARCHAR(500),
role VARCHAR(500))""")

curr.execute(rawcredits_table_create)
conn.commit()

# %% [markdown]
# Inserting the data into the tables

# %%
rawtitles_insert = ("""INSERT INTO rawtitles(
id,
title,
type,
release_year,
age_certification,
runtime,
genre,
production_countries,
seasons,
imdb_id,
imdb_score,
imdb_votes)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""")

# %%
for i, row in RawTitles.iterrows():
    #print(list(row))
    curr.execute(rawtitles_insert, list(row))

conn.commit()

# %%
rawcredits_insert = ("""INSERT INTO rawcredits(
person_id,
id,
name,
fic_character,
role)
VALUES(%s, %s, %s, %s, %s)""")

# %%
for i, row in RawCredits.iterrows():
    curr.execute(rawcredits_insert, list(row))
    
conn.commit()

# %% [markdown]
# Loading the tables into the dataframes after applying joins and segrating data in MySQL

# %%
NetflixMovies = pd.read_csv("/Users/shikharyadav/Desktop/Semester 2 - Spring 2023/Portfolio Projects/Netflix - Data Modeling & Exploration/NetflixMovies.csv")
NetflixShows = pd.read_csv("/Users/shikharyadav/Desktop/Semester 2 - Spring 2023/Portfolio Projects/Netflix - Data Modeling & Exploration/NetflixShows.csv")

# %% [markdown]
# Doing Exploratory Data Analysis

# %%
NetflixMovies.head()
# Out:
#                                       Title              Actor Name   Role  \
# 0                         C/o Kancharapalem      Praveena Paruchuri  ACTOR
# 1      Chhota Bheem & Krishna in Mayanagari                 Krishna  ACTOR
# 2  David Attenborough: A Life on Our Planet              Max Hughes  ACTOR
# 3                         C/o Kancharapalem  Kishore Kumar Polimera  ACTOR
# 4                         C/o Kancharapalem         Karthik Rathnam  ACTOR
#
#    Released Year Age Certification  Runtime          Genre  \
# 0           2018                PG      152          drama
# 1           2011                 G       66      animation
# 2           2020                PG       83  documentation
# 3           2018                PG      152          drama
# 4           2018                PG      152          drama
#
#   Production Countries  IMDB Score  Number of Votes
# 0                   IN         9.0           6562.0
# 1                   IN         9.0              5.0
# 2                   GB         9.0          31180.0
# 3                   IN         9.0           6562.0
# 4                   IN         9.0           6562.0

# %%
NetflixShows.head()
# Out:
#                         Title     Actor Name   Role  Released Year  \
# 0                Breaking Bad      Anna Gunn  ACTOR           2008
# 1                Breaking Bad   Betsy Brandt  ACTOR           2008
# 2  Avatar: The Last Airbender  Jessie Flower  ACTOR           2005
# 3  Avatar: The Last Airbender     Zach Tyler  ACTOR           2005
# 4  Avatar: The Last Airbender  Cricket Leigh  ACTOR           2005
#
#   Age Certification  Runtime  Genre Production Countries  Seasons Broadcasted  \
# 0             TV-MA       48  drama                   US                    5
# 1             TV-MA       48  drama                   US                    5
# 2             TV-Y7       24  scifi                   US                    3
# 3             TV-Y7       24  scifi                   US                    3
# 4             TV-Y7       24  scifi                   US                    3
#
#    IMDB Score  Number of Votes
# 0         9.5        1727694.0
# 1         9.5        1727694.0
# 2         9.3         297336.0
# 3         9.3         297336.0
# 4         9.3         297336.0

# %%
pd.unique(NetflixMovies['Age Certification'])
# Out:
# array(['PG', 'G', nan, 'PG-13', 'R', 'NC-17'], dtype=object)

# %%
pd.unique(NetflixMovies['Genre'])
# Out:
# array(['drama', 'animation', 'documentation', 'comedy', 'scifi',
#        'romance', 'music', 'western', 'action', 'crime', 'thriller',
#        'fantasy', 'horror', 'war', 'family', 'sport', 'history', nan],
#       dtype=object)

# %%
#finding out the unique values in the Genre column
pd.unique(NetflixShows['Genre'])
# Out:
# array(['drama', 'scifi', 'comedy', 'documentation', 'history', 'crime',
#        'western', 'action', 'reality', 'sport', 'war', 'animation',
#        'romance', 'thriller', 'fantasy', 'family', nan, 'horror', 'music'],
#       dtype=object)

# %% [markdown]
# Pattern Recognition using Correlation

# %%
#installing dython library to find the correlation of categorical variables
# !pip install dython
# Out:
# Collecting dython
#   Downloading dython-0.7.3-py3-none-any.whl (23 kB)
# Collecting scikit-plot>=0.3.7
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas>=1.4.2 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from dython) (1.4.2)
# Requirement already satisfied: scipy>=1.7.1 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from dython) (1.7.3)
# Collecting psutil>=5.9.1
#   Downloading psutil-5.9.4-cp36-abi3-macosx_10_9_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 2.8 MB/s eta 0:00:01
# Collecting matplotlib>=3.5.3
#   Downloading matplotlib-3.6.2-cp39-cp39-macosx_10_12_x86_64.whl (7.3 MB)
#      |████████████████████████████████| 7.3 MB 23.5 MB/s eta 0:00:01
# Collecting seaborn>=0.12.0
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 14.7 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.24.2 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from dython) (1.0.2)
# Collecting numpy>=1.23.0
#   Downloading numpy-1.24.1-cp39-cp39-macosx_10_9_x86_64.whl (19.8 MB)
#      |████████████████████████████████| 19.8 MB 28.9 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (21.3)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp39-cp39-macosx_10_9_x86_64.whl (240 kB)
#      |████████████████████████████████| 240 kB 152.7 MB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.5.3->dython) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.4.2->dython) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->dython) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.2->dython) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/shikharyadav/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.2->dython) (1.1.0)
# Collecting scipy>=1.7.1
#   Downloading scipy-1.10.0-cp39-cp39-macosx_10_15_x86_64.whl (35.2 MB)
#      |████████████████████████████████| 35.2 MB 48.0 MB/s eta 0:00:011
# Installing collected packages: numpy, scipy, contourpy, matplotlib, seaborn, scikit-plot, psutil, dython
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.1
#     Uninstalling matplotlib-3.5.1:
#       Successfully uninstalled matplotlib-3.5.1
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.8.0
#     Uninstalling psutil-5.8.0:
#       Successfully uninstalled psutil-5.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.1 which is incompatible.
# Successfully installed contourpy-1.0.6 dython-0.7.3 matplotlib-3.6.2 numpy-1.24.1 psutil-5.9.4 scikit-plot-0.3.7 scipy-1.10.0 seaborn-0.12.2

# %%
from dython.nominal import associations

# %%
from dython.nominal import identify_nominal_columns

# %%
#finding out the categorical variables using dython library
categorical_features_movies = identify_nominal_columns(NetflixMovies)
categorical_features_movies
# Out:
# ['Title',
#  'Actor Name',
#  'Role',
#  'Age Certification',
#  'Genre',
#  'Production Countries']

# %%
#dropping the unnecessary columns
NetflixMovies.drop(NetflixMovies.columns[[0,1,2]], axis = 1, inplace = True)
NetflixShows.drop(NetflixShows.columns[[0,1,2]], axis = 1, inplace = True)

# %% [markdown]
# Generating Correlation Matrix and Heat-Map

# %%
# using associations function of dython library which uses Pearson's R for continous-continous coses, 
# Correlation Ration for categorical-continous cases, Cramer's V or Theil's U for categorical-categorical cases

correlation_movies = associations(NetflixMovies, figsize = (10,10))
df_corr_movies=correlation_movies['corr']
df_corr_movies.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm',
                                                                                             axis=None).set_precision(2)
# Out:
# /var/folders/c6/l07hm63n1bl3v3b51p2g2cdw0000gn/T/ipykernel_28053/1107304657.py:6: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_corr_movies.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm',
# <style type="text/css">
# #T_23ef1_row0_col0, #T_23ef1_row1_col1, #T_23ef1_row2_col2, #T_23ef1_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_23ef1_row0_col1, #T_23ef1_row1_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_23ef1_row0_col2, #T_23ef1_row0_col3, #T_23ef1_row2_col0, #T_23ef1_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_23ef1_row1_col2, #T_23ef1_row2_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_23ef1_row1_col3, #T_23ef1_row3_col1 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_23ef1_row2_col3, #T_23ef1_row3_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_23ef1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23ef1_level0_col0" class="col_heading level0 col0" >Genre</th>
#       <th id="T_23ef1_level0_col1" class="col_heading level0 col1" >Production Countries</th>
#       <th id="T_23ef1_level0_col2" class="col_heading level0 col2" >IMDB Score</th>
#       <th id="T_23ef1_level0_col3" class="col_heading level0 col3" >Number of Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23ef1_level0_row0" class="row_heading level0 row0" >Genre</th>
#       <td id="T_23ef1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_23ef1_row0_col1" class="data row0 col1" >0.40</td>
#       <td id="T_23ef1_row0_col2" class="data row0 col2" >0.24</td>
#       <td id="T_23ef1_row0_col3" class="data row0 col3" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_23ef1_level0_row1" class="row_heading level0 row1" >Production Countries</th>
#       <td id="T_23ef1_row1_col0" class="data row1 col0" >0.40</td>
#       <td id="T_23ef1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_23ef1_row1_col2" class="data row1 col2" >0.43</td>
#       <td id="T_23ef1_row1_col3" class="data row1 col3" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_23ef1_level0_row2" class="row_heading level0 row2" >IMDB Score</th>
#       <td id="T_23ef1_row2_col0" class="data row2 col0" >0.24</td>
#       <td id="T_23ef1_row2_col1" class="data row2 col1" >0.43</td>
#       <td id="T_23ef1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_23ef1_row2_col3" class="data row2 col3" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_23ef1_level0_row3" class="row_heading level0 row3" >Number of Votes</th>
#       <td id="T_23ef1_row3_col0" class="data row3 col0" >0.24</td>
#       <td id="T_23ef1_row3_col1" class="data row3 col1" >0.44</td>
#       <td id="T_23ef1_row3_col2" class="data row3 col2" >0.32</td>
#       <td id="T_23ef1_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
correlation_shows = associations(NetflixShows, figsize = (10,10))
df_corr_Shows=correlation_shows['corr']
df_corr_Shows.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm',
                                                                                             axis=None).set_precision(2)
# Out:
# /var/folders/c6/l07hm63n1bl3v3b51p2g2cdw0000gn/T/ipykernel_28053/1159711282.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_corr_Shows.dropna(axis=1, how='all').dropna(axis=0, how='all').style.background_gradient(cmap='coolwarm',
# <style type="text/css">
# #T_9fba5_row0_col0, #T_9fba5_row1_col1, #T_9fba5_row2_col2, #T_9fba5_row3_col3, #T_9fba5_row4_col4, #T_9fba5_row5_col5, #T_9fba5_row6_col6, #T_9fba5_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9fba5_row0_col1, #T_9fba5_row1_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_9fba5_row0_col2, #T_9fba5_row2_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_9fba5_row0_col3, #T_9fba5_row3_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_9fba5_row0_col4, #T_9fba5_row4_col0 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_9fba5_row0_col5, #T_9fba5_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9fba5_row0_col6, #T_9fba5_row6_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9fba5_row0_col7, #T_9fba5_row7_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9fba5_row1_col2, #T_9fba5_row2_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_9fba5_row1_col3, #T_9fba5_row3_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_9fba5_row1_col4, #T_9fba5_row4_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_9fba5_row1_col5, #T_9fba5_row3_col4, #T_9fba5_row4_col3, #T_9fba5_row5_col1, #T_9fba5_row5_col7, #T_9fba5_row7_col5 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_9fba5_row1_col6, #T_9fba5_row6_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_9fba5_row1_col7, #T_9fba5_row7_col1 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_9fba5_row2_col3, #T_9fba5_row3_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_9fba5_row2_col4, #T_9fba5_row4_col2 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_9fba5_row2_col5, #T_9fba5_row5_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_9fba5_row2_col6, #T_9fba5_row6_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_9fba5_row2_col7, #T_9fba5_row7_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_9fba5_row3_col5, #T_9fba5_row3_col6, #T_9fba5_row5_col3, #T_9fba5_row6_col3 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_9fba5_row3_col7, #T_9fba5_row7_col3 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_9fba5_row4_col5, #T_9fba5_row5_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9fba5_row4_col6, #T_9fba5_row6_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_9fba5_row4_col7, #T_9fba5_row7_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_9fba5_row5_col6, #T_9fba5_row6_col5 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_9fba5_row6_col7, #T_9fba5_row7_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_9fba5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fba5_level0_col0" class="col_heading level0 col0" >Released Year</th>
#       <th id="T_9fba5_level0_col1" class="col_heading level0 col1" >Age Certification</th>
#       <th id="T_9fba5_level0_col2" class="col_heading level0 col2" >Runtime</th>
#       <th id="T_9fba5_level0_col3" class="col_heading level0 col3" >Genre</th>
#       <th id="T_9fba5_level0_col4" class="col_heading level0 col4" >Production Countries</th>
#       <th id="T_9fba5_level0_col5" class="col_heading level0 col5" >Seasons Broadcasted</th>
#       <th id="T_9fba5_level0_col6" class="col_heading level0 col6" >IMDB Score</th>
#       <th id="T_9fba5_level0_col7" class="col_heading level0 col7" >Number of Votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fba5_level0_row0" class="row_heading level0 row0" >Released Year</th>
#       <td id="T_9fba5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_9fba5_row0_col1" class="data row0 col1" >0.34</td>
#       <td id="T_9fba5_row0_col2" class="data row0 col2" >0.17</td>
#       <td id="T_9fba5_row0_col3" class="data row0 col3" >0.24</td>
#       <td id="T_9fba5_row0_col4" class="data row0 col4" >0.36</td>
#       <td id="T_9fba5_row0_col5" class="data row0 col5" >-0.58</td>
#       <td id="T_9fba5_row0_col6" class="data row0 col6" >-0.08</td>
#       <td id="T_9fba5_row0_col7" class="data row0 col7" >-0.15</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row1" class="row_heading level0 row1" >Age Certification</th>
#       <td id="T_9fba5_row1_col0" class="data row1 col0" >0.34</td>
#       <td id="T_9fba5_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_9fba5_row1_col2" class="data row1 col2" >0.40</td>
#       <td id="T_9fba5_row1_col3" class="data row1 col3" >0.26</td>
#       <td id="T_9fba5_row1_col4" class="data row1 col4" >0.35</td>
#       <td id="T_9fba5_row1_col5" class="data row1 col5" >0.28</td>
#       <td id="T_9fba5_row1_col6" class="data row1 col6" >0.21</td>
#       <td id="T_9fba5_row1_col7" class="data row1 col7" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row2" class="row_heading level0 row2" >Runtime</th>
#       <td id="T_9fba5_row2_col0" class="data row2 col0" >0.17</td>
#       <td id="T_9fba5_row2_col1" class="data row2 col1" >0.40</td>
#       <td id="T_9fba5_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_9fba5_row2_col3" class="data row2 col3" >0.42</td>
#       <td id="T_9fba5_row2_col4" class="data row2 col4" >0.50</td>
#       <td id="T_9fba5_row2_col5" class="data row2 col5" >-0.18</td>
#       <td id="T_9fba5_row2_col6" class="data row2 col6" >0.13</td>
#       <td id="T_9fba5_row2_col7" class="data row2 col7" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row3" class="row_heading level0 row3" >Genre</th>
#       <td id="T_9fba5_row3_col0" class="data row3 col0" >0.24</td>
#       <td id="T_9fba5_row3_col1" class="data row3 col1" >0.26</td>
#       <td id="T_9fba5_row3_col2" class="data row3 col2" >0.42</td>
#       <td id="T_9fba5_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_9fba5_row3_col4" class="data row3 col4" >0.28</td>
#       <td id="T_9fba5_row3_col5" class="data row3 col5" >0.24</td>
#       <td id="T_9fba5_row3_col6" class="data row3 col6" >0.23</td>
#       <td id="T_9fba5_row3_col7" class="data row3 col7" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row4" class="row_heading level0 row4" >Production Countries</th>
#       <td id="T_9fba5_row4_col0" class="data row4 col0" >0.36</td>
#       <td id="T_9fba5_row4_col1" class="data row4 col1" >0.35</td>
#       <td id="T_9fba5_row4_col2" class="data row4 col2" >0.50</td>
#       <td id="T_9fba5_row4_col3" class="data row4 col3" >0.28</td>
#       <td id="T_9fba5_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_9fba5_row4_col5" class="data row4 col5" >0.36</td>
#       <td id="T_9fba5_row4_col6" class="data row4 col6" >0.34</td>
#       <td id="T_9fba5_row4_col7" class="data row4 col7" >0.27</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row5" class="row_heading level0 row5" >Seasons Broadcasted</th>
#       <td id="T_9fba5_row5_col0" class="data row5 col0" >-0.58</td>
#       <td id="T_9fba5_row5_col1" class="data row5 col1" >0.28</td>
#       <td id="T_9fba5_row5_col2" class="data row5 col2" >-0.18</td>
#       <td id="T_9fba5_row5_col3" class="data row5 col3" >0.24</td>
#       <td id="T_9fba5_row5_col4" class="data row5 col4" >0.36</td>
#       <td id="T_9fba5_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_9fba5_row5_col6" class="data row5 col6" >0.09</td>
#       <td id="T_9fba5_row5_col7" class="data row5 col7" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row6" class="row_heading level0 row6" >IMDB Score</th>
#       <td id="T_9fba5_row6_col0" class="data row6 col0" >-0.08</td>
#       <td id="T_9fba5_row6_col1" class="data row6 col1" >0.21</td>
#       <td id="T_9fba5_row6_col2" class="data row6 col2" >0.13</td>
#       <td id="T_9fba5_row6_col3" class="data row6 col3" >0.23</td>
#       <td id="T_9fba5_row6_col4" class="data row6 col4" >0.34</td>
#       <td id="T_9fba5_row6_col5" class="data row6 col5" >0.09</td>
#       <td id="T_9fba5_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_9fba5_row6_col7" class="data row6 col7" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_9fba5_level0_row7" class="row_heading level0 row

# %% [markdown]
# Conclusion - As evident from the correlation matrices above, there is no correlation among the variables so it's not ideal to build a linear regression or any other machine learning model to predict any target variable in the data.
